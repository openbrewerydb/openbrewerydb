# %% [markdown]
# # Open Brewery DB Notebook

# %%
import numpy as np
import pandas as pd
import datetime
from slugify import slugify

# %%
df = pd.read_csv('breweries.csv', header=0)

# %%
df.head()
# Out:
#                                    id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 1           10-barrel-brewing-co-bend             10 Barrel Brewing Co
# 2         10-barrel-brewing-co-bend-2             10 Barrel Brewing Co
# 3  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
#
#   brewery_type                       street address_2 address_3   city  \
# 0        micro                400 Brown Cir       NaN       NaN   Knox
# 1        large                62970 18th St       NaN       NaN   Bend
# 2        large  1135 NW Galveston Ave Ste B       NaN       NaN   Bend
# 3        large             62950 NE 18th St       NaN       NaN   Bend
# 4        large             826 W Bannock St       NaN       NaN  Boise
#
#      state county_province postal_code              website_url       phone  \
# 0  Indiana             NaN       46534                      NaN  6308165790
# 1   Oregon             NaN  97701-9847  http://www.10barrel.com  5415851007
# 2   Oregon             NaN  97703-2465                      NaN  5415851007
# 3   Oregon             NaN       97701                      NaN  5415851007
# 4    Idaho             NaN  83702-5857  http://www.10barrel.com  2083445870
#
#             created_at           updated_at        country   longitude  \
# 0  2018-07-24 01:33:21  2018-08-24 00:32:25  United States  -86.627954
# 1  2018-07-24 01:34:04  2018-08-11 21:39:09  United States         NaN
# 2  2018-07-24 01:34:04  2018-08-11 21:39:09  United States         NaN
# 3  2018-07-24 01:34:04  2018-08-24 15:45:44  United States -121.280954
# 4  2018-07-24 01:33:17  2020-10-11 17:00:13  United States -116.202929
#
#     latitude  tags
# 0  41.289715   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3  44.091211   NaN
# 4  43.618516   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7797 entries, 0 to 7796
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               7797 non-null   object
#  1   name             7797 non-null   object
#  2   brewery_type     7797 non-null   object
#  3   street           6974 non-null   object
#  4   address_2        8 non-null      object
#  5   address_3        2 non-null      object
#  6   city             7797 non-null   object
#  7   state            7787 non-null   object
#  8   county_province  10 non-null     object
#  9   postal_code      7797 non-null   object
#  10  website_url      6608 non-null   object
#  11  phone            6997 non-null   object
#  12  created_at       7797 non-null   object
#  13  updated_at       7797 non-null   object
#  14  country          7797 non-null   object
#  15  longitude        4932 non-null   float64
#  16  latitude         4932 non-null   float64
#  17  tags             0 non-null      float64
# dtypes: float64(3), object(15)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Clean-up

# %%
# Get rid of rows without `country`
# Commenting these out because we might not need them anymore
df.dropna(subset=['country'], inplace=True)

# %%
# Fill empty `created_at` and `updated_at` values with current datetime
# Commenting these out because we might not need them anymore
# current_datetime = datetime.datetime.now().isoformat()
# df.created_at.fillna(current_datetime, inplace=True)
# df.updated_at.fillna(current_datetime, inplace=True)

# %%
# Let's fix any rows Excel destroyed.
# Commenting these out because we might not need them anymore
# df.loc[df.created_at.str.match('1900'),'created_at'] = '2018-07-24 01:34:37'
# df.loc[df.updated_at.str.match('1900'),'updated_at'] = '2018-07-24 01:34:37'

# %%
# Commenting these out because we might not need them anymore
df['city'] = df['city'].str.strip()

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7797 entries, 0 to 7796
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               7797 non-null   object
#  1   name             7797 non-null   object
#  2   brewery_type     7797 non-null   object
#  3   street           6974 non-null   object
#  4   address_2        8 non-null      object
#  5   address_3        2 non-null      object
#  6   city             7797 non-null   object
#  7   state            7787 non-null   object
#  8   county_province  10 non-null     object
#  9   postal_code      7797 non-null   object
#  10  website_url      6608 non-null   object
#  11  phone            6997 non-null   object
#  12  created_at       7797 non-null   datetime64[ns]
#  13  updated_at       7797 non-null   datetime64[ns]
#  14  country          7797 non-null   object
#  15  longitude        4932 non-null   float64
#  16  latitude         4932 non-null   float64
#  17  tags             0 non-null      float64
# dtypes: datetime64[ns](2), float64(3), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Duplicates

# %%
len(df['id'].unique())
# Out:
# 7797

# %%
df['name_city'] = df['name'] + " " + df['city']
df['new_id'] = df['name_city'].apply(slugify)

# %%
# Iterate through duplicates and add incremental numbers. Ex. "10-barrel-bend-1" and "10-barrel-bend-2"

# Get all of the duplicates
df_dups = df[df.duplicated(['new_id'], keep=False)]

# For each duplicate row...
for _, row in df_dups.iterrows():
    print(f"Updating {row['new_id']}...")
    # Create a temporary dataframe of all of the duplicated rows
    df_temp = df[df['new_id'] == row['new_id']]
    
    # Loop over each of the same rows and update the `new_id` with sequential numbers
    count = 0
    for index, value in df_temp.iterrows():
        count += 1
        if count == 1: 
            print(f"{value['new_id']}")
            continue
        print(f"{value['new_id']}-{str(count)}")
        df.loc[index, 'new_id'] = f"{value['new_id']}-{str(count)}"
# Out:
# Updating peoria-artisan-brewery-peoria...
# peoria-artisan-brewery-peoria
# peoria-artisan-brewery-peoria-2
# Updating peoria-artisan-brewery-peoria...
# peoria-artisan-brewery-peoria
# Updating brewery-in-planning-claremont-claremont...
# brewery-in-planning-claremont-claremont
# brewery-in-planning-claremont-claremont-2
# Updating brewery-in-planning-claremont-claremont...
# brewery-in-planning-claremont-claremont
# Updating bootleggers-brewery-fullerton...
# bootleggers-brewery-fullerton
# bootleggers-brewery-fullerton-2
# Updating bootleggers-brewery-fullerton...
# bootleggers-brewery-fullerton
# Updating highland-park-brewery-los-angeles...
# highland-park-brewery-los-angeles
# highland-park-brewery-los-angeles-2
# Updating highland-park-brewery-los-angeles...
# highland-park-brewery-los-angeles
# Updating ballast-point-brewing-company-san-diego...
# ballast-point-brewing-company-san-diego
# ballast-point-brewing-company-san-diego-2
# Updating ballast-point-brewing-company-san-diego...
# ballast-point-brewing-company-san-diego
# Updating peak-to-peak-tap-brew-aurora...
# peak-to-peak-tap-brew-aurora
# peak-to-peak-tap-brew-aurora-2
# Updating peak-to-peak-tap-brew-aurora...
# peak-to-peak-tap-brew-aurora
# Updating brewery-in-planning-denver-denver...
# brewery-in-planning-denver-denver
# brewery-in-planning-denver-denver-2
# Updating brewery-in-planning-denver-denver...
# brewery-in-planning-denver-denver
# tired-hands-brewing-co-ardmore
# tired-hands-brewing-co-ardmore-2
# Updating tired-hands-brewing-co-ardmore...
# tired-hands-brewing-co-ardmore
# Updating old-forge-brewing-co-danville...
# old-forge-brewing-co-danville
# old-forge-brewing-co-danville-2
# Updating old-forge-brewing-co-danville...
# old-forge-brewing-co-danville
# Updating brewery-in-planning-philadelphia-philadelphia...
# brewery-in-planning-philadelphia-philadelphia
# brewery-in-planning-philadelphia-philadelphia-2
# Updating brewery-in-planning-philadelphia-philadelphia...
# brewery-in-planning-philadelphia-philadelphia
# Updating d-g-yuengling-and-son-inc-pottsville...
# d-g-yuengling-and-son-inc-pottsville
# d-g-yuengling-and-son-inc-pottsville-2
# Updating d-g-yuengling-and-son-inc-pottsville...
# d-g-yuengling-and-son-inc-pottsville
# Updating brewery-in-planning-knoxville-knoxville...
# brewery-in-planning-knoxville-knoxville
# brewery-in-planning-knoxville-knoxville-2
# Updating brewery-in-planning-knoxville-knoxville...
# brewery-in-planning-knoxville-knoxville
# Updating brewery-in-planning-austin-austin...
# brewery-in-planning-austin-austin
# brewery-in-planning-austin-austin-2
# brewery-in-planning-austin-austin-3
# Updating brewery-in-planning-austin-austin...
# brewery-in-planning-austin-austin
# Updating brewery-in-planning-austin-austin...
# brewery-in-planning-austin-austin
# Updating brewery-in-planning-washington-washington...
# brewery-in-planning-washington-washington
# Updating four-corners-brewing-co-dallas...
# four-corners-brewing-co-dallas
# four-corners-brewing-co-dallas-2
# Updating four-corners-brewing-co-dallas...
# four-corners-brewing-co-dallas
# Updating texas-beer-company-taylor...
# texas-beer-company-taylor
# texas-beer-company-taylor-2
# Updating texas-beer-company-taylor...
# texas-beer-company-taylor
# Updating epic-brewing-co-llc-salt-lake-city...
# epic-brewing-co-llc-salt-lake-city
# epic-brewing-co-llc-salt-lake-city-2
# Updating epic-brewing-co-llc-salt-lake-city...
# epic-brewing-co-llc-salt-lake-city
# Updating zero-gravity-craft-brewery-burlington...
# zero-gravity-craft-brewery-burlington
# zero-gravity-craft-brewery-burlington-2
# Updating zero-gravity-craft-brewery-burlington...
# zero-gravity-craft-brewery-burlington
# Updating badwolf-brewing-company-manassas...
# badwolf-brewing-company-manassas
# badwolf-brewing-company-manassas-2
# Updating badwolf-brewing-company-manassas...
# badwolf-brewing-company-manassas
# Updating brewery-in-planning-seattle-seattle...
# brewery-in-planning-seattle-seattle
# brewery-in-planning-seattle-seattle-2
# Updating brewery-in-planning-seattle-seattle...
# brewery-in-planning-seattle-seattle
# Updating elysian-brewing-co-seattle...
# elysian-brewing-co-seattle
# elysian-brewing-co-seattle-2
# Updating elysian-brewing-co-seattle...
# elysian-brewing-co-seattle

# %%
len(df['new_id'].unique())
# Out:
# 8011

# %%
df['id'] = df['new_id']
df.drop(columns=['new_id', 'name_city'], inplace=True)

# %%
len(df['id'].unique())
# Out:
# 8011

# %% [markdown]
# ## Save CSV

# %%
df.to_csv('breweries.csv', index=False)
